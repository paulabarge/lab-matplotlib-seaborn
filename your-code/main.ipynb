# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Using pyplot
myplot = plt.plot(x,y, label="double", color ="r",linewidth=5)
myplot = plt.plot(x,z, label="quadratic", color ="g", linestyle="--")
plt.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Using OO Interface
fig, (ax1,ax2)  = plt.subplots(1,2)

a = ax1.plot(x,y,label="double", color ="r",linewidth=5)
b = ax2.plot(x,z,label="quadratic",color ="g", linestyle="--")

ax1.legend()
ax2.legend()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, (ax1,ax2)  = plt.subplots(1,2, figsize=(10,7))

plt.ylabel("Valuey")
plt.title("Double and cuadratic version of x")
a = ax1.plot(x,y,label="double")
b = ax2.plot(x,z,label="quadratic")

ax2.legend()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
#These are the two functions: 
a = x**2
b = np.e**x


#defining the function
fig, (ax1,ax2)  = plt.subplots(1,2) #two columns because there are two different functions. 

ax1.plot(a) #cuadratic
ax2.plot(b) #logarithmical

#setting scale to log 
ax2.set_yscale("log")

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
fig, (ax1,ax2)  = plt.subplots(1,2) #two columns because there are two different functions. 


ax1.plot(a, label="cuadratic") #cuadratic
ax2.plot(b, label="napierian") #logarithmical


ax2.set_yscale("log")
ax2.legend()
ax1.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv("../Datasets as CSV/Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 4))

plt.sca(ax1)
fitbit.groupby("Months_encoded")["Steps"].mean().plot()
plt.xticks(range(12),["January","February","March","April","May","June","July","August","September","October","November","December"])
plt.title("Median Steps by month")

# MEDIAN STEPS BY WORK_OR_WEEKEND
plt.sca(ax2)
fitbit.groupby("Work_or_Weekend")["Steps"].median().plot.bar()
plt.xticks(range(2),["Weekend","Weekday"])
plt.title("Median Steps by Weekday or weekend")
# Out:
# Text(0.5, 1.0, 'Median Steps by Weekday or weekend')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
columns = ["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]

ax1.scatter(fitbit["Steps"], fitbit["Minutes Lightly Active"])
ax2.scatter(fitbit["Steps"], fitbit["Minutes Very Active"])
ax3.scatter(fitbit["Steps"], fitbit["Minutes Sedentary"])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("../Datasets as CSV/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['float64','int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include =["object"])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import seaborn as sns
sns.set()

plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
melted_titanic = titanic.melt(id_vars="PassengerId", value_vars="Age")
melted_titanic

sns.boxplot(x="variable", y="value", data=melted_titanic)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
f, ax = plt.subplots(1, 3, figsize=(12, 8))
bins = [10, 20, 50]

for i in range(3):
    plt.sca(ax[i])
    titanic['Age'].hist(bins = bins[i])
    plt.title(f'number of bins is {bins[i]}')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
It makes n numbers of columns, first 10, then 20, then 50
"""
# Out:
# '\nIt makes n numbers of columns, first 10, then 20, then 50\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
melted_titanic = titanic.melt(id_vars="PassengerId", value_vars="Age")
sns.catplot(x="value", y="variable", data=melted_titanic)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
# Method 1 - matplotlib
gender = titanic.Gender.value_counts()
gender.plot.bar()

# %%
# Method 2 - seaborn
sns.countplot(titanic["Gender"])

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.distplot(titanic["Pclass"])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(titanic["Age"])

# %%
"""
A boxplot will let us know the average age of the passengers and also the outliers.
"""
# Out:
# '\nA boxplot will let us know the average age of the passengers and also the outliers.\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Most of the passengers of the Titanic were between 20 and 35 years old. 
The distribution is slightly skewed to the left.
"""
# Out:
# '\nMost of the passengers of the Titanic were between 20 and 35 years old. \nThe distribution is slightly skewed to the left.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
fare = titanic["Fare"]
age = titanic["Age"]
plt.scatter(fare, age)

# %%
# Method 2 - seaborn
fare = titanic["Fare"]
age = titanic["Age"]
sns.scatterplot(fare,age)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()
sns.heatmap(corr)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
SibSP and Parch are the most correlated variables with a value between 0,4 and 0,6
"""
# Out:
# '\nSibSP and Parch are the most correlated variables with a value between 0,4 and 0,6\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x=titanic["Pclass"], y=titanic["Age"], data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
melted_titanic = titanic.melt(id_vars=['Gender'], value_vars=['Age'])
g = sns.FacetGrid(data=melted_titanic, col="Gender", col_order=["Age"])
g.map(plt.plot, 'Gender', 'Age')
